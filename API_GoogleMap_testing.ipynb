# %%
import requests
api_key = "AIzaSyBJ88fUHeMJXZ6DQud9R-PKqFLDFKt-jC0"

# %% [markdown]
# ### testing route 1

# %%
# origin_rawtext = "Gatech Gryo's  Brother"
# destination_rawtext = "Klaus Computing Building"

# %% [markdown]
# ### testing route 2

# %%
origin_rawtext = "Gatech Gryo's  Brother"
destination_rawtext = "Klaus Computing Building|CRC" #Multiple Destinations

# %% [markdown]
# ### User Input

# %%
# user_input_origin = "CODA Building"
# user_input_destination = "Klaus Computing Building, CRC"

# if ',' in user_input_origin:
#     origin_rawtest = user_input_origin.replace(',', '|')
#     orgins = user_input_origin.split(',')

# else:
#     origin_rawtest = user_input_origin
#     origins = [user_input_origin]

# if ',' in user_input_destination:
#     destination_rawtest = user_input_destination.replace(',', '|')
#     destinations = user_input_destination.split(',')

# else:
#     destination_rawtest = user_input_destination
#     destinations = [user_input_destination]

# %%
origins = "CODA Building" #User Input
destination1 = "Klaus Computing Building" #Destination 1
destination2 = "Atlantic Stations" #Destination 2

# %%
import urllib3
from urllib.parse import quote
origin = quote(origins)
destination = quote(f'{destination1}|{destination2}')
# origin = "Boston%2CMA%7CCharlestown%2CMA"
# destination = "Lexington%2CMA%7CConcord%2CMA"
depature_time = "now"

# %%
destination
# Out:
# 'Klaus%20Computing%20Building%7CAtlantic%20Stations'

# %%
url = f"https://maps.googleapis.com/maps/api/distancematrix/json?origins={origin}&destinations={destination}&departure_time={depature_time}&key={api_key}"

payload={}
headers = {}

# %%
response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "destination_addresses" : [
#       "266 Ferst Dr NW, Atlanta, GA 30332, USA",
#       "Atlantic Station, Atlanta, GA, USA"
#    ],
#    "origin_addresses" : [ "85 5th St NW B, Atlanta, GA 30308, USA" ],
#    "rows" : [
#       {
#          "elements" : [
#             {
#                "distance" : {
#                   "text" : "0.5 km",
#                   "value" : 483
#                },
#                "duration" : {
#                   "text" : "2 mins",
#                   "value" : 90
#                },
#                "duration_in_traffic" : {
#                   "text" : "2 mins",
#                   "value" : 95
#                },
#                "status" : "OK"
#             },
#             {
#                "distance" : {
#                   "text" : "2.4 km",
#                   "value" : 2432
#                },
#                "duration" : {
#                   "text" : "6 mins",
#                   "value" : 373
#                },
# ...

# %%
#Reading the response object as json
response.json()
# Out:
# {'destination_addresses': ['266 Ferst Dr NW, Atlanta, GA 30332, USA',
#   'Atlantic Station, Atlanta, GA, USA'],
#  'origin_addresses': ['85 5th St NW B, Atlanta, GA 30308, USA'],
#  'rows': [{'elements': [{'distance': {'text': '0.5 km', 'value': 483},
#      'duration': {'text': '2 mins', 'value': 90},
#      'duration_in_traffic': {'text': '2 mins', 'value': 95},
#      'status': 'OK'},
#     {'distance': {'text': '2.4 km', 'value': 2432},
#      'duration': {'text': '6 mins', 'value': 373},
#      'duration_in_traffic': {'text': '6 mins', 'value': 389},
#      'status': 'OK'}]}],
#  'status': 'OK'}

# %%
npossible_routes = len(destination_rawtest.split(',')) + 1
# a = [idx for idx in range(npossible_routes)]
min_time = 1e99
min_idx = -1
for idx in range(npossible_routes):
    traveltime = response.json()['rows'][0]['elements'][idx]['duration']['value']
    if traveltime < min_time:
        min_time = traveltime
        min_idx = idx

# %%
routes = []

# %% [markdown]
# ### Designin Routes

# %%
first_destination_address = response.json()['destination_addresses'][min_idx]
first_destination_name = destinations[min_idx]
second_idx = [idx for idx in range(npossible_routes) if idx != min_idx][0]
second_destination_address = response.json()['destination_addresses'][second_idx]
second_destination_name = destinations[second_idx]

routes.append((origins, first_destination_name))
routes.append((first_destination_name, second_destination_name))

print(first_destination_name, "--", first_destination_address)
print(second_destination_name, "--", second_destination_address)
print('\n')
print(routes)
# Out:
# Klaus Computing Building -- 266 Ferst Dr NW, Atlanta, GA 30332, USA
#  CRC -- Atlantic Station, Atlanta, GA, USA
#
#
# [('CODA Building', 'Klaus Computing Building'), ('Klaus Computing Building', ' CRC')]

# %% [markdown]
# ### Finding Directions for Selected Routes

# %%
directions_response = []

# %%
for (origin, destination) in routes:
    url = f"https://maps.googleapis.com/maps/api/directions/json?origin={origin}&destination={destination}&key={api_key}"
    payload={}
    headers = {}
    response = requests.request("GET", url, headers=headers, data=payload)
    directions_response.append(response)

# %%
print(directions_response[1].text)
# Out:
# {
#    "geocoded_waypoints" : [
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJpS60CuyBt4cR7EB78yfJ7hY",
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       },
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJK6-i_c7T8IcRubdF_jyGJp8",
#          "types" : [ "establishment", "point_of_interest" ]
#       }
#    ],
#    "routes" : [
#       {
#          "bounds" : {
#             "northeast" : {
#                "lat" : 43.6876154,
#                "lng" : -84.39082739999999
#             },
#             "southwest" : {
#                "lat" : 33.7770202,
#                "lng" : -92.9848831
#             }
#          },
#          "copyrights" : "Map data ©2021 Google",
#          "legs" : [
#             {
#                "distance" : {
#                   "text" : "995 mi",
#                   "value" : 1601323
#                },
#                "duration" : {
# ...
